# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("dataset_Facebook.csv",sep=";")
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
p_subset=df[df['Type']=='Photo']
p_subset.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
p_subset.shape
# Out:
# (426, 19)

# %%
df['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
s_subset=df[df['Type']=='Status']
s_subset
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
s_subset.shape
# Out:
# (45, 19)

# %%
v_subset=df[df['Type']=='Video']
v_subset.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 74             137893  Video         1          11             3         11
# 183            134879  Video         1           9             2         10
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 74    0.0                      13544                            30235
# 183   0.0                      30624                            56950
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
v_subset.shape
# Out:
# (7, 19)

# %%
merge_data=pd.concat([p_subset,v_subset])
merge_data.head()
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441  Photo         2          12             4          3
# 2            139441  Photo         3          12             3          3
# 3            139441  Photo         2          12             2         10
# 4            139441  Photo         2          12             2          3
# 6            139441  Photo         3          12             1          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 6   1.0                      11692                            19479
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
merge_data.shape
# Out:
# (433, 19)

# %%
m_data=pd.concat([s_subset,v_subset])
m_data.shape
# Out:
# (52, 19)

# %%
sort_data=df.sort_values(by=['like'])
sort_data
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
s_data=df.sort_values(by=['share'])
s_data.shape
# Out:
# (500, 19)

# %%
df1=df.transpose()
df1.head()
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...    490    491    492    493  \
# Page total likes  139441  139441  139441  ...  85979  85979  85979  85093
# Type               Photo  Status   Photo  ...  Photo  Photo   Link  Photo
# Category               3       2       3  ...      3      3      1      3
# Post Month            12      12      12  ...      1      1      1      1
# Post Weekday           7       7       6  ...      6      6      5      1
#
#                     494    495    496    497    498    499
# ...

# %%
df1.shape
# Out:
# (19, 500)

# %%
melt_data=pd.melt(df,id_vars=['Type'],var_name='Metrics',value_name='Count')
melt_data
# Out:
#         Type             Metrics     Count
# 0      Photo    Page total likes  139441.0
# 1     Status    Page total likes  139441.0
# 2      Photo    Page total likes  139441.0
# 3      Photo    Page total likes  139441.0
# 4      Photo    Page total likes  139441.0
# ...      ...                 ...       ...
# 8995   Photo  Total Interactions      84.0
# 8996   Photo  Total Interactions      75.0
# 8997   Photo  Total Interactions     115.0
# 8998   Photo  Total Interactions     136.0
# 8999   Photo  Total Interactions     119.0
#
# [9000 rows x 3 columns]

# %%
p_data=pd.pivot_table(df,index=['Type','Category'],values='share')
p_data.head()
# Out:
#                     share
# Type  Category
# Link  1         12.700000
#       2         15.000000
#       3         15.000000
# Photo 1         17.961326
#       2         35.505495

# %%
casting=pd.pivot_table(df,index=['Category','Type'],values='like',aggfunc=sum)
casting
# Out:
#                     like
# Category Type
# 1        Link     1513.0
#          Photo   23184.0
#          Status    409.0
#          Video    1620.0
# 2        Link       32.0
#          Photo   21463.0
#          Status   6937.0
# 3        Link       68.0
#          Photo   32963.0
#          Status    606.0

# %%
casting.shape
# Out:
# (10, 1)
