# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Iris.csv',header=None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.columns=['Sepallengthcm','Sepalwidthcm','Petallengthcm','Petalwidthcm','Species']
df.head()
# Out:
#    Sepallengthcm  Sepalwidthcm  Petallengthcm  Petalwidthcm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
s1=df[df['Species']=='Iris-setosa']
s1.head()
# Out:
#    Sepallengthcm  Sepalwidthcm  Petallengthcm  Petalwidthcm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
s2=df[df['Species']=='Iris-versicolor']
s2.head()
# Out:
#     Sepallengthcm  Sepalwidthcm  Petallengthcm  Petalwidthcm          Species
# 50            7.0           3.2            4.7           1.4  Iris-versicolor
# 51            6.4           3.2            4.5           1.5  Iris-versicolor
# 52            6.9           3.1            4.9           1.5  Iris-versicolor
# 53            5.5           2.3            4.0           1.3  Iris-versicolor
# 54            6.5           2.8            4.6           1.5  Iris-versicolor

# %%
m_data=pd.concat([s1,s2])
m_data.head()
# Out:
#    Sepallengthcm  Sepalwidthcm  Petallengthcm  Petalwidthcm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df1=df.transpose()
df1.head()
# Out:
#                        0            1            2            3    \
# Sepallengthcm          5.1          4.9          4.7          4.6
# Sepalwidthcm           3.5          3.0          3.2          3.1
# Petallengthcm          1.4          1.4          1.3          1.5
# Petalwidthcm           0.2          0.2          0.2          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                        4            5            6            7    \
# Sepallengthcm          5.0          5.4          4.6          5.0
# Sepalwidthcm           3.6          3.9          3.4          3.4
# Petallengthcm          1.4          1.7          1.4          1.5
# Petalwidthcm           0.2          0.4          0.3          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                        8            9    ...             140             141  \
# Sepallengthcm          4.4          4.9  ...             6.7             6.9
# ...

# %%
melt=pd.melt(df,id_vars=['Species'],var_name='Feature',value_name='Count')
melt.head()
# Out:
#        Species        Feature  Count
# 0  Iris-setosa  Sepallengthcm    5.1
# 1  Iris-setosa  Sepallengthcm    4.9
# 2  Iris-setosa  Sepallengthcm    4.7
# 3  Iris-setosa  Sepallengthcm    4.6
# 4  Iris-setosa  Sepallengthcm    5.0

# %%
float=pd.pivot_table(df,index=['Species'],values=['Sepallengthcm','Sepalwidthcm'])
float.head()
# Out:
#                  Sepallengthcm  Sepalwidthcm
# Species
# Iris-setosa              5.006         3.418
# Iris-versicolor          5.936         2.770
# Iris-virginica           6.588         2.974
